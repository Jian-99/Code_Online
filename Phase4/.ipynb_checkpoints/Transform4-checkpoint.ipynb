# %%
from Convert2MNIST import *
Convert_img_to_csv('/Users/johnson/Desktop/Research/Phase4/CroppedYale')
# Out:
# Path: /Users/johnson/Desktop/Research/Phase4/CroppedYale/yaleB01
# Image: yaleB01_P00A+110E+15.pgm
# Image: yaleB01_P00A+025E+00.pgm
# Image: yaleB01_P00A-085E+20.pgm
# Image: yaleB01_P00A+035E+15.pgm
# Image: yaleB01_P00A+095E+00.pgm
# Image: yaleB01_P00A-070E-35.pgm
# Image: yaleB01_P00A-020E+10.pgm
# Image: yaleB01_P00A-060E-20.pgm
# Image: yaleB01_P00A-085E-20.pgm
# Image: yaleB01_P00A+050E-40.pgm
# Image: yaleB01_P00A+070E+00.pgm
# Image: yaleB01_P00A-035E-20.pgm
# Image: yaleB01_P00A-060E+20.pgm
# Image: yaleB01_P00A-110E-20.pgm
# Image: yaleB01_P00A-020E-10.pgm
# Image: yaleB01_P00A-035E+40.pgm
# Image: yaleB01_P00A-050E+00.pgm
# Image: yaleB01_P00A+020E-40.pgm
# Image: yaleB01_P00A-110E+40.pgm
# Image: yaleB01_P00A+010E+00.pgm
# Image: yaleB01_P00A+000E+00.pgm
# Image: yaleB01_P00A-005E+10.pgm
# Image: yaleB01_P00A-070E+45.pgm
# Image: yaleB01_P00A-120E+00.pgm
# Image: yaleB01_P00A+035E+65.pgm
# Image: yaleB01_P00A+110E+65.pgm
# Image: yaleB01_P00A+130E+20.pgm
# Image: yaleB01_P00A-005E-10.pgm
# Image: yaleB01_P00A+015E+20.pgm
# Image: yaleB01_P00A-010E-20.pgm
# Image: yaleB01_P00A+000E+20.pgm
# Image: yaleB01_P00A+070E+45.pgm
# Image: yaleB01_P00A+005E+10.pgm
# Image: yaleB01_P00A+110E+40.pgm
# Image: yaleB01_P00A-010E+00.pgm
# Image: yaleB01_P00A+035E+40.pgm
# Image: yaleB01_P00A+050E+00.pgm
# Image: yaleB01_P00A-020E-40.pgm
# Image: yaleB01_P00A-015E+20.pgm
# Image: yaleB01_P00A+000E-20.pgm
# Image: yaleB01_P00A+010E-20.pgm
# Image: yaleB01_P00A+000E-35.pgm
# Image: yaleB01_P00A-130E+20.pgm
# Image: yaleB01_P00A+005E-10.pgm
# Image: yaleB01_P00A-110E+65.pgm
# Image: yaleB01_P00A+120E+00.pgm
# Image: yaleB01_P00A-035E+65.pgm
# Image: yaleB01_P00A+020E+10.pgm
# Image: yaleB01_P00A+060E-20.pgm
# Image: yaleB01_P00A-095E+00.pgm
# Image: yaleB01_P00A+070E-35.pgm
# Image: yaleB01_P00A-035E+15.pgm
# Image: yaleB01_P00A-110E+15.pgm
# Image: yaleB01_P00A+085E+20.pgm
# Image: yaleB01_P00A-025E+00.pgm
# Image: yaleB01_P00A+000E+45.pgm
# Image: yaleB01_P00A+110E-20.pgm
# Image: yaleB01_P00A+060E+20.pgm
# Image: yaleB01_P00A+020E-10.pgm
# Image: yaleB01_P00_Ambient.pgm
# Image: yaleB01_P00A+035E-20.pgm
# Image: yaleB01_P00A-070E+00.pgm
# Image: yaleB01_P00A+085E-20.pgm
# Image: yaleB01_P00A-050E-40.pgm
# Image: yaleB01_P00A+000E+90.pgm
# Path: /Users/johnson/Desktop/Research/Phase4/CroppedYale/yale
pgm
# Path: /Users/johnson/Desktop/Research/Phase4/CroppedYale/yaleB03
# Image: yaleB03_P00A+050E+00.pgm
# Image: yaleB03_P00A-020E-40.pgm
# Image: yaleB03_P00A+035E+40.pgm
# Image: yaleB03_P00A+110E+40.pgm
# Image: yaleB03_P00A-010E+00.pgm
# Image: yaleB03_P00A+005E+10.pgm
# Image: yaleB03_P00A+000E+20.pgm
# Image: yaleB03_P00A+070E+45.pgm
# Image: yaleB03_P00A-035E+65.pgm
# Image: yaleB03_P00A+120E+00.pgm
# Image: yaleB03_P00A-110E+65.pgm
# Image: yaleB03_P00_Ambient.pgm
# Image: yaleB03_P00A-130E+20.pgm
# Image: yaleB03_P00A+005E-10.pgm
# Image: yaleB03_P00A+000E-35.pgm
# Image: yaleB03_P00A+000E-20.pgm
# Image: yaleB03_P00A+010E-20.pgm
# Image: yaleB03_P00A-015E+20.pgm
# Image: yaleB03_P00A-110E+15.pgm
# Image: yaleB03_P00A-025E+00.pgm
# Image: yaleB03_P00A+085E+20.pgm
# Image: yaleB03_P00A-035E+15.pgm
# Image: yaleB03_P00A-095E+00.pgm
# Image: yaleB03_P00A+070E-35.pgm
# Image: yaleB03_P00A+060E-20.pgm
# Image: yaleB03_P00A+020E+10.pgm
# Image: yaleB03_P00A-050E-40.pgm
# Image: yaleB03_P00A+000E+90.pgm
# Image: yaleB03_P00A+085E-20.pgm
# Image: yaleB03_P00A-070E+00.pgm
# Image: yaleB03_P00A+035E-20.pgm
# Image: yaleB03_P00A+020E-10.pgm
# Image: yaleB03_P00A+000E+45.pgm
# Image: yaleB03_P00A+110E-20.pgm
# Image: yaleB03_P00A+060E+20.pgm
# Image: yaleB03_P00A-060E-20.pgm
# Image: yaleB03_P00A-020E+10.pgm
# Image: yaleB03_P00A+095E+00.pgm
# Image: yaleB03_P00A-070E-35.pgm
# Image: yaleB03_P00A+035E+15.pgm
# Image: yaleB03_P00A+110E+15.pgm
# Image: yaleB03_P00A-085E+20.pgm
# Image: yaleB03_P00A+025E+00.pgm
# Image: yaleB03_P00A-020E-10.pgm
# Image: yaleB03_P00A-060E+20.pgm
# Image: yaleB03_P00A-110E-20.pgm
# Image: yaleB03_P00A-035E-20.pgm
# Image: yaleB03_P00A+070E+00.pgm
# Image: yaleB03_P00A+050E-40.pgm
# Image: yaleB03_P00A-085E-20.pgm
# Image: yaleB03_P00A-070E+45.pgm
# Image: yaleB03_P00A-005E+10.pgm
# Image: yaleB03_P00A-110E+40.pgm
# Image: yaleB03_P00A+010E+00.pgm
# Image: yaleB03_P00A+000E+00.pgm
# Image: yaleB03_P00A-050E+00.pgm
# Image: yaleB03_P00A+020E-40.pgm
# Image: yaleB03_P00A-035E+40.pgm
# Image: yaleB03_P00A-010E-20.pgm
# Image: yaleB03_P00A+015E+20.pgm
# Image: yaleB03_P00A+130E+20.pgm
# Image: yaleB03_P00A-005E-10.pgm
# Image: yaleB03_P00A+110E+65.pgm
# Image: yaleB03_P00A+035E+65.pgm
# Image: yaleB03_P00A-120E+00.pgm
# Path: /Users/johnson/Desktop/Research/Phase4/CroppedYale/yale
# Image: yaleB07_P00A+015E+20.pgm
# Image: yaleB07_P00A+020E-40.pgm
# Image: yaleB07_P00A-050E+00.pgm
# Image: yaleB07_P00A-035E+40.pgm
# Image: yaleB07_P00A+010E+00.pgm
# Image: yaleB07_P00A+000E+00.pgm
# Image: yaleB07_P00A-110E+40.pgm
# Image: yaleB07_P00A-005E+10.pgm
# Image: yaleB07_P00A-070E+45.pgm
# Path: /Users/johnson/Desktop/Research/Phase4/CroppedYale/yaleB08
# Image: yaleB08_P00A+005E+10.pgm
# Image: yaleB08_P00A+000E+20.pgm
# Image: yaleB08_P00A+070E+45.pgm
# Image: yaleB08_P00A+035E+40.pgm
# Image: yaleB08_P00A+050E+00.pgm
# Image: yaleB08_P00A-020E-40.pgm
# Image: yaleB08_P00A+110E+40.pgm
# Image: yaleB08_P00A-010E+00.pgm
# Image: yaleB08_P00A+000E-35.pgm
# Image: yaleB08_P00A-130E+20.pgm
# Image: yaleB08_P00A+005E-10.pgm
# Image: yaleB08_P00A-015E+20.pgm
# Image: yaleB08_P00A+010E-20.pgm
# Image: yaleB08_P00A+000E-20.pgm
# Image: yaleB08_P00A+120E+00.pgm
# Image: yaleB08_P00A-035E+65.pgm
# Image: yaleB08_P00A-110E+65.pgm
# Image: yaleB08_P00A-095E+00.pgm
# Image: yaleB08_P00A+070E-35.pgm
# Image: yaleB08_P00A+020E+10.pgm
# Image: yaleB08_P00A+060E-20.pgm
# Image: yaleB08_P00A-110E+15.pgm
# Image: yaleB08_P00A-025E+00.pgm
# Image: yaleB08_P00A+085E+20.pgm
# Image: yaleB08_P00A-035E+15.pgm
# Image: yaleB08_P00A+035E-20.pgm
# Image: yaleB08_P00A+000E+45.pgm
# Image: yaleB08_P00A+110E-20.pgm
# Image: yaleB08_P00A+060E+20.pgm
# Image: yaleB08_P00A+020E-10.pgm
# Image: yaleB08_P00A+085E-20.pgm
# Image: yaleB08_P00A-050E-40.pgm
# Image: yaleB08_P00A+000E+90.pgm
# Image: yaleB08_P00A-070E+00.pgm
# Image: yaleB08_P00A+035E+15.pgm
# Image: yaleB08_P00A+110E+15.pgm
# Image: yaleB08_P00A-085E+20.pgm
# Image: yaleB08_P00A+025E+00.pgm
# Image: yaleB08_P00A-020E+10.pgm
# Image: yaleB08_P00A-060E-20.pgm
# Image: yaleB08_P00A+095E+00.pgm
# Image: yaleB08_P00A-070E-35.pgm
# Image: yaleB08_P00A+070E+00.pgm
# Image: yaleB08_P00_Ambient.pgm
# Image: yaleB08_P00A-085E-20.pgm
# Image: yaleB08_P00A+050E-40.pgm
# Image: yaleB08_P00A-060E+20.pgm
# Image: yaleB08_P00A-110E-20.pgm
# Image: yaleB08_P00A-020E-10.pgm
# Image: yaleB08_P00A-035E-20.pgm
# Image: yaleB08_P00A-110E+40.pgm
# Image: yaleB08_P00A+000E+00.pgm
# Image: yaleB08_P00A+010E+00.pgm
# Image: yaleB08_P00A-035E+40.pgm
# Image: yaleB08_P00A-050E+00.pgm
# Image: yaleB08_P00A+020E-40.pgm
# Image: yaleB08_P00A-070E+45.pgm
# Image: yaleB08_P00A-005E+10.pgm
# Image: yaleB08_P00A+110E+65.pgm
# Image: yaleB08_P00A-120E+00.pgm
# Image: yaleB08_P00A+035E+65.pgm
# Image: yaleB08_P00A+015E+20.pgm
# Image: yaleB08_P00A-010E-20.pgm
# Image: yaleB08_P00A+130E+20.pgm
# Image: yaleB08_P00A-005E-10.pgm
# Path: /Users/johnson/Desktop/Research/Phase4/CroppedYale/yaleB09
# Image: yaleB09_P00A+060E-20.pgm
# Image: yaleB09_P00A+020E+10.pgm
# Image: yaleB09_P00A+070E-35.pgm
# Image: yaleB09_P00A-095E+00.pgm
# Image: yaleB09_P00A-025E+00.pgm
# Image: yaleB09_P00A+085E+20.pgm
# Image: yaleB09_P00A-110E+15.pgm
# Image: yaleB09_P00A+020E-10.pgm
# Image: yaleB09_P00A+060E+20.pgm
# Image: yaleB09_P00A+110E-20.pgm
# Image: yaleB09_P00A+000E+45.pgm
# Image: yaleB09_P00A+035E-20.pgm
# Image: yaleB09_P00A-070E+00.pgm
# Image: yaleB09_P00A+000E+90.pgm
# Image: yaleB09_P00A-050E-40.pgm
# Image: yaleB09_P00A+085E-20.pgm
# Image: yaleB09_P00A+070E+45.pgm
# Image: yaleB09_P00A+000E+20.pgm
# Image: yaleB09_P00A+005E+10.pgm
# Image: yaleB09_P00A-010E+00.pgm
# Image: yaleB09_P00A+110E+40.pgm
# Image: yaleB09_P00A-020E-40.pgm
# Image: yaleB09_P00A+050E+00.pgm
# Image: yaleB09_P00A+035E+40.pgm
# Image: yaleB09_P00A+000E-20.pgm
# Image: yaleB09_P00A+010E-20.pgm
# Image: yaleB09_P00A-015E+20.pgm
# Image: yaleB09_P00A+005E-10.pgm
# Image: yaleB09_P00A-130E+20.pgm
# Image: yaleB09_P00A+000E-35.pgm
# Image: yaleB09_P00A-110E+65.pgm
# Image: yaleB09_P00A-035E+65.pgm
# Image: yaleB09_P00A+120E+00.pgm
# Image: yaleB09_P00A+020E-40.pgm
# Image: yaleB09_P00A-050E+00.pgm
# Image: yaleB09_P00A-035E+40.pgm
# Image: yaleB09_P00A+010E+00.pgm
# Image: yaleB09_P00A+000E+00.pgm
# Image: yaleB09_P00A-110E+40.pgm
# Image: yaleB09_P00A-005E+10.pgm
# Image: yaleB09_P00A-070E+45.pgm
# Image: yaleB09_P00A+035E+65.pgm
# Image: yaleB09_P00A-120E+00.pgm
# Image: yaleB09_P00A+110E+65.pgm
# Image: yaleB09_P00A-005E-10.pgm
# Image: yaleB09_P00A+130E+20.pgm
# Image: yaleB09_P00A-010E-20.pgm
# Image: yaleB09_P00A+015E+20.pgm
# Image: yaleB09_P00A-085E+20.pgm
# Image: yaleB09_P00A+025E+00.pgm
# Image: yaleB09_P00_Ambient.pgm
# Image: yaleB09_P00A+110E+15.pgm
# Image: yaleB09_P00A+035E+15.pgm
# Image: yaleB09_P00A-070E-35.pgm
# Image: yaleB09_P00A+095E+00.pgm
# Image: yaleB09_P00A-060E-20.pgm
# Image: yaleB09_P00A-020E+10.pgm
# Image: yaleB09_P00A+050E-40.pgm
# Image: yaleB09_P00A-085E-20.pgm
# Image: yaleB09_P00A+070E+00.pgm
# Image: yaleB09_P00A-035E-20.pgm
# Image: yaleB09_P00A-020E-10.pgm
# Image: yaleB09_P00A-110E-20.pgm
# Image: yaleB09_P00A-060E+20.pgm
# All Good

# %%
import pandas as pd
import keras
import numpy as np
from keras.models import Sequential
from keras.layers import Dense

input_data = pd.read_csv("./MNIST/Train.csv")
y = input_data['label']
input_data.drop('label',axis=1,inplace = True)
X = input_data
y = pd.get_dummies(y)
classifier = Sequential()
classifier.add(Dense(units = 300, kernel_initializer ='uniform', activation = 'relu', input_dim = 32256))
classifier.add(Dense(units = 200, kernel_initializer ='uniform', activation = 'relu'))
classifier.add(Dense(units = 100, kernel_initializer ='uniform', activation = 'relu'))
classifier.add(Dense(units = 9, kernel_initializer ='uniform', activation = 'sigmoid'))
classifier.compile(optimizer = 'sgd', loss = 'mean_squared_error', metrics = ['accuracy'])
classifier.fit(X, y, batch_size = 10, epochs = 30)

test_data = pd.read_csv("./Test/Test.csv")
y_pred = classifier.predict(test_data)
np.savetxt("result.csv", y_pred, delimiter=",")
# Out:
# Epoch 1/30
# 583/583 [==============================] - 4s 7ms/step - loss: 0.1303 - acc: 0.1304
# Epoch 2/30
# 583/583 [==============================] - 3s 6ms/step - loss: 0.1104 - acc: 0.1647
# Epoch 3/30
# 583/583 [==============================] - 3s 6ms/step - loss: 0.1073 - acc: 0.1921
# Epoch 4/30
# 583/583 [==============================] - 3s 6ms/step - loss: 0.1011 - acc: 0.2367
# Epoch 5/30
# 583/583 [==============================] - 3s 6ms/step - loss: 0.0958 - acc: 0.2693
# Epoch 6/30
# 583/583 [==============================] - 3s 6ms/step - loss: 0.0909 - acc: 0.2985
# Epoch 7/30
# 583/583 [==============================] - 3s 6ms/step - loss: 0.0859 - acc: 0.3516
# Epoch 8/30
# 583/583 [==============================] - 3s 6ms/step - loss: 0.0817 - acc: 0.3962
# Epoch 9/30
# 583/583 [==============================] - 3s 6ms/step - loss: 0.0753 - acc: 0.4288
# Epoch 10/30
# 583/583 [==============================] - 3s 6ms/step - loss: 0.0703 - acc: 0.4700
# Epoch 11/30
# 583/583 [==============================] - 4s 6ms/step - loss: 0.0666 - acc: 0.5077
# Epoch 12/30
# 583/583 [==============================] - 3s 6ms/step - loss: 0.0627 - acc: 0.5472
# Epoch 13/30
# 583/583 [==============================] - 3s 6ms/step - loss: 0.0585 - acc: 0.5798
# Epoch 14/30
# 583/583 [==============================] - 4s 6ms/step - loss: 0.0544 - acc: 0.6038
# Epoch 15/30
# 583/583 [==============================] - 3s 6ms/step - loss: 0.0509 - acc: 0.6244
# Epoch 16/30
# 583/583 [==============================] - 3s 6ms/step - loss: 0.0480 - acc: 0.6552
# Epoch 17/30
# 583/583 [==============================] - 3s 6ms/step - loss: 0.0444 - acc: 0.6758
# Epoch 18/30
# 583/583 [==============================] - 3s 6ms/step - loss: 0.0414 - acc: 0.7084
# Epoch 19/30
# 583/583 [==============================] - 3s 6ms/step - loss: 0.0380 - acc: 0.7341
# Epoch 20/30
# 583/583 [==============================] - 4s 6ms/step - loss: 0.0359 - acc: 0.7530
# Epoch 21/30
# 583/583 [==============================] - 4s 6ms/step - loss: 0.0341 - acc: 0.7616
# Epoch 22/30
# 583/583 [==============================] - 3s 6ms/step - loss: 0.0325 - acc: 0.7719
# Epoch 23/30
# 583/583 [==============================] - 3s 6ms/step - loss: 0.0310 - acc: 0.7787
# Epoch 24/30
# 583/583 [==============================] - 3s 6ms/step - loss: 0.0296 - acc: 0.7873
# Epoch 25/30
# 583/583 [==============================] - 3s 6ms/step - loss: 0.0287 - acc: 0.7925
# Epoch 26/30
# 583/583 [==============================] - 3s 6ms/step - loss: 0.0281 - acc: 0.7942
# Epoch 27/30
# 583/583 [==============================] - 3s 6ms/step - loss: 0.0275 - acc: 0.8062
# Epoch 28/30
# 583/583 [==============================] - 3s 6ms/step - loss: 0.0272 - acc: 0.8079
# Epoch 29/30
# 583/583 [==============================] - 3s 6ms/step - loss: 0.0264 - acc: 0.8165
# Epoch 30/30
# 583/583 [==============================] - 3s 6ms/step - loss: 0.0255 - acc: 0.8216
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-8e8fd16c84f6> in <module>
#      19
#      20 test_data = pd.read_csv("./Test/Test.csv")
# ---> 21 y_pred = classifier.predict(test_data)
#      22 np.savetxt("result.csv", y_pred, delimiter=",")
#
# /anaconda3/lib/python3.7/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps)
#    1147                              'argument.')
#    1148         # Validate user data.
# -> 1149         x, _, _ = self._standardize_user_data(x)
#    1150         if self.stateful:
#    1151             if x[0].shape[0] > batch_size and x[0].shape[0] % batch_size != 0:
#
# /anaconda3/lib/python3.7/site-packages/keras/engine/training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_array_lengths, batch_size)
#     749             feed_input_shapes,
#     750             check_batch_axis=False,  # Don't enforce the batch size.
# --> 751             exception_prefix='input')
#     752
#     753         if y is not None:
#
# /anaconda3/lib/python3.7/site-packages/keras/engine/training_utils.py in standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     136                             ': expected ' + names[i] + ' to have shape ' +
#     137                             str(shape) + ' but got array with shape ' +
# --> 138                             str(data_shape))
#     139     return data
#     140
#
# ValueError: Error when checking input: expected dense_21_input to have shape (32256,) but got array with shape (32255,)

# %%
import csv,os,cv2
with open('/Users/johnson/Desktop/Research/Phase4/Test/Test.csv',"w",newline="") as file:
    #Set up CSV columns
    column_name = (["pixel%d"%i for i in range(0,1)])
    column_name.extend(["pixel%d"%i for i in range(1,168*192)])
    writer = csv.writer(file)
    writer.writerow(column_name)
    folder = './Test'
    img_list = os.listdir(folder)
    #Loop thru all images
    for img_name in img_list:
        if os.path.splitext(img_name)[1] == '.pgm':
            print ("Image:",img_name)
            img_path = os.path.join(folder,img_name)
            img = cv2.imread(img_path,-1)
            blurred = cv2.GaussianBlur(img,(3,3),0)
            img = cv2.Canny(blurred,55,120,apertureSize = 3)
            row_data = (img.flatten())
            writer.writerow(row_data)
# Out:
# Image: yaleB09_P00A-035E+15.pgm
# Image: yaleB07_P00A-025E+00.pgm

# %%
import numpy as np
test_data = pd.read_csv("./Test/Test.csv")
y_pred = classifier.predict(test_data)
np.savetxt("result.csv", y_pred, delimiter=",")

# %%
import pandas as pd
csvfile = pd.read_csv('/Users/johnson/Desktop/Research/Phase4/result.csv')
#csvfile.columns=['01','02','03','04','05','06','07','08','']
csvfile.insert(1) #= ['01','02','03','04','05','06','07','08','09']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-5a8bd976e0c3> in <module>
#       2 csvfile = pd.read_csv('/Users/johnson/Desktop/Research/Phase4/result.csv')
#       3 #csvfile.columns=['01','02','03','04','05','06','07','08','']
# ----> 4 csvfile.insert(1) #= ['01','02','03','04','05','06','07','08','09']
#       5
#       6
#
# TypeError: insert() missing 2 required positional arguments: 'column' and 'value'

# %%
from Convert2MNIST import *
Convert_test()
# Out:
# Image: yaleB09_P00A-035E+15.pgm
# Image: yaleB07_P00A-025E+00.pgm

# %%
import csv

row = ['01','02','03','04','05','06','07','08','09']

with open('result.csv', 'r') as readFile:
    reader = csv.reader(readFile)
    lines = list(reader)
    lines.insert(0, row)

with open('result.csv', 'w', newline='') as writeFile:
    writer = csv.writer(writeFile)
    writer.writerows(lines)

readFile.close()
writeFile.close()

# %%
with open('result.csv', 'r') as csv:
     first_line = csv.readline()
     data = csv.readlines()

ncol = first_line.count(',') + 1 
print(ncol)
# Out:
# 9

# %%
with open('result.csv', 'r') as csv:
     first_line = csv.readline()
     data = csv.readlines()

ncol = first_line.count(',') + 1 
label = []

for element in range (1,ncol+1):
    label.append(element)

print (label)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
import csv
from Result import *
Get_result()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-fd3188c7674a> in <module>
#       1 import csv
#       2 from Result import *
# ----> 3 Get_result()
#
# ~/Desktop/Research/Phase4/Result.py in Get_result()
#      24     #Insert the labels in the first row
#      25     with open('result.csv', 'r') as readFile:
# ---> 26         reader = csv.reader(readFile)
#      27         lines = list(reader)
#      28         lines.insert(0, row)
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'reader'
